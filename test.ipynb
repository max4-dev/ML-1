# %%
# !pip3 install cianparser
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 11.3 MB 18.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 346 kB 14.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 15.7 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import cianparser

moscow_parser = cianparser.CianParser(location="Клин")
data = moscow_parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":1, "end_page":1000})

print(data)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# /Users/maksimbogomyakov/Desktop/python/ML-1/cian_flat_sale_1_1000_klin_23_Oct_2024_10_35_00_383457.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175004&deal_type=sale&offer_type=flat&room1=1&room2=1
#
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 17 978 530 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=175004&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 2 page...
#
#
#
# ...

# %%
COUNT_FILES = 23

objs = []

for i in range(1, COUNT_FILES):
  with open(f"file{i}.csv", 'r') as temp_f:
    col_count = [ len(l.split(",")) for l in temp_f.readlines() ]

  column_names = [i for i in range(0, max(col_count))]

  csv = pd.read_csv(f"file{i}.csv", header=None, delimiter=",", names=column_names)
  objs.append(csv)

combined_df = pd.concat(objs, axis=0, ignore_index=True)
print(combined_df)
combined_df.to_csv('all.csv', index=False)
# Out:
#                                                        0    1   2
# 0      author;author_type;url;location;deal_type;acco...  NaN NaN
# 1      Зеленый сад;developer;https://zhukovsky.cian.r...  NaN NaN
# 2      СОВКОМБАНК;official_representative;https://zhu...  NaN NaN
# 3      Зеленый сад;developer;https://zhukovsky.cian.r...  NaN NaN
# 4      ID 105760738;homeowner;https://zhukovsky.cian....  NaN NaN
# ...                                                  ...  ...  ..
# 10271  Яищу;real_estate_agent;https://bronnicy.cian.r...  NaN NaN
# 10272  ID 114876782;homeowner;https://bronnicy.cian.r...  NaN NaN
# 10273  ID 120311735;homeowner;https://bronnicy.cian.r...  NaN NaN
# 10274  Этажи Воскресенск-Раменское;real_estate_agent;...  NaN NaN
# 10275  Марина Папкова;realtor;https://voskresensk.cia...  NaN NaN
#
# [10276 rows x 3 columns]
