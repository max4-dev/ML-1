# %%
# !pip3 install cianparser
# !pip3 install pandas

# %%
import cianparser

parser = cianparser.CianParser(location="Долгопрудный")
data = parser.get_flats(deal_type="sale", rooms=1, with_extra_data=True, with_saving_csv=True, additional_settings={"start_page":1, "end_page":1000})

print(data)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# /Users/maksimbogomyakov/Desktop/python/ML-1/cian_flat_sale_1_1000_dolgoprudnyj_27_Oct_2024_12_08_04_964511.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=flat&room1=1
#
#
# Exception: HTTPSConnectionPool(host='cian.ru', port=443): Max retries exceeded with url: /cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=flat&room1=1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# ...
